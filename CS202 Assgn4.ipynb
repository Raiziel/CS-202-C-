# %% [markdown]
# // Program written by Nicholas Munoz 2000781568
#
# #include <iostream>
# #include <iomanip>
# #include <string>
# #include "boardType.h"
# using namespace std;
# class magicSquareType: public boardType
# {
# 	public:
# string title;
# magicSquareType(int, string); //  constructor should set the title and use the base class constructor to allow the base class to create the grid.
# void createMagicSquare(); // should create a magic square based on the current order using one of the provided algorithms.
# const void printMagicSquare(); //  function should display some header information CS 202 – Magic Squares the title, order, and magic number.
# void readMagicSquare(); //  function should prompt the user for a title (ensuring it is not empty)
# const bool validateMagicSquare(); // function should validate a magic square by ensuring the sum of each column,row,each two main diagonals sum magic number
# void clearMagicSquare(); // function should reset each cell entry to 0 and clear the title string
# const int magicNumber(); // function should return the magic number or sum based on the board size or order
# const string getTitle(); //  function should return the current title value
# void setTitle(string); //  function should set the title to the passed value.
# };
#
# /////////////////////////////////
# const bool validateMagicSquare();
# {    n = boardType.size;
#
#      if (n == square[10][10])
#               return true;
#      else
#               return false;
# }
# ////////////////////////////////
#
#
#
#
# ////////////////////////////////
# void setTitle(string);
# {
# cout << " Enter Title Name of your magic Square" << endl;
# cin >> title;
# return title;
# }
# ///////////////////////////////
#
#
#
#
# ////////////////////////////////////
# const int magicNumber();
# { n =
#   magicNumber = ((n*n*n + n)/2);
#   return magicNumber;
# }
# ////////////////////////////////////
#
#
#
# ///////////////////////////////
# const void printMagicSquare();
# {cout << "Magic Square for n "<< n <<" sum is " <<  magicNumber(); << endl;
#     for (i = 0; i < n; i++)
#     {
#         for (j = 0; j < n; j++)
#             cout << magicSquare[i][j]< <" ";
#         cout << endl;
#     }
# }
# ///////////////////////////////
#
#
# ///////////////////////////////////////////
# void createMagicSquare ();
# { // function start
# int n = boardType.getOrder();
# int magicSquare[n][n]; // set matrix nxn
#
# memset(magicSquare,0,sizeof(magicSquare)); // initialize all values to zero
# // Starting Position One
#     if(n%2==1)
# 	{
# 	int i = n/2;
#     int j = n-1;
#     // Set all values square by square
#     for (int num = 1; num <= n*n; )
#     {
#         if (i == -1 && j == n) //3rd condition
#         {
#             j = n-2;
#             i = 0;
#         }
#         else
#         {
#             // conditions makes sure to stay in bounds of our square
#             if (j == n)
#                 {
# 				j = 0;
# 				}
#
#             if (i < 0)
#                 {
# 				i = n - 1;
# 				}
#         }
#         if (magicSquare[i][j]) //2nd condition
#         {
#             j -= 2;
#             i++;
#             continue;
#         }
#         else
#             magicSquare[i][j] = num++; //set number
#
#         j++; i--; //1st condition
#     } // for
#     } // if
#  } // function end
# ///////////////////////////////////////////////////////
#
#
# int main()
# {
# // ---------------------------------------
# //  Misc. delcarations.
#
# 	string	stars;
# 	stars.append(60,'*');
# 	int	i=1;
#
# 	boardType brd0(3);
# 	boardType brd1(11);
# 	boardType brd2(12);
#
# // ---------------------------------------
# //  These declarations should give error message...
#
# 	cout << endl;
# 	cout << "*** Error Testing " << stars << endl;
# 	cout << " 5 Declaration errors..." << endl;
# 	cout << endl;
#
# 	boardType badBrd1(1);
# 	boardType badBrd2(60);
# 	boardType badBrd3(-6);
# 	boardType badBrd4(0);
# 	boardType badBrd5(2);
#
# // ---------------------------------------
# //  These invalid board access should give error message...
#
# 	cout << endl << "*** Error Testing " << stars << endl;
# 	cout << " 4 invalid board locations..." << endl << endl;
#
# 	if (badBrd1.getCell(1,1) != 0)
# 		cout << "Error accessing badBrd1." << endl;
# 	badBrd1.setCell(1,1,1);
#
# 	if (badBrd2.getCell(0,0) != 0)
# 		cout << "Error accessing badBrd2." << endl;
# 	badBrd2.setCell(0,0,1);
#
# 	cout << endl << "Output badBrd3 (should be empty):" << endl;
# 	badBrd3.printGrid();
#
# // ---------------------------------------
# //  Print board 0, 3x3 -> should be all 0's.
#
# 	cout << "*** Board #0 " << stars << endl;
# 	cout << " 3 x 3 -> All zero's" << endl;
# 	cout << endl;
#
# 	brd0.printGrid();
#
# // ---------------------------------------
# //  Try some functions with board #1
# //	when brd1 goes out of scope, destructor is called...
#
# 	cout << "*** Board #1 " << stars << endl;
# 	cout << " 11 x 11 -> numbered" << endl;
# 	cout << endl;
#
# 	{
# 		for (int r=0; r<brd1.getOrder(); r++)
# 			for (int c=0; c<brd1.getOrder(); c++)
# 				brd1.setCell(r,c,i++);
#
# 		brd1.printGrid();
# 	}
#
# // ---------------------------------------
# //  Try some functions with board #2
# //	NOTE, to see the printed magic square grid correctly
# //	on the screen, it will be necessary to expand the size
#
# 	cout << "*** Board #2 " << stars << endl;
# 	cout << " 12 x 12 -> 1's in main diagonals, 0's otherwise." << endl;
# 	cout << " 5 bad board location accesses..." << endl;
# 	cout << endl;
#
# 	brd2.setCell(0,12,1);		// error
# 	brd2.setCell(12,0,1);		// error
# 	brd2.setCell(12,12,1);		// error
# 	brd2.setCell(0,-1,1);		// error
# 	brd2.setCell(-1,0,1);		// error
#
# 	for (int i=0; i<brd2.getOrder(); i++)
# 		brd2.setCell(i,i,1);
#
# 	for (int i=0, j=11; i<brd2.getOrder(); i++, j--)
# 		brd2.setCell(i,j,1);
#
# 	brd2.printGrid();
#
# 	cout << stars << endl;
# 	cout << endl;
#
# // ---------------------------------------
# //  All done.
#
# 	return 0;
# }

# %% [markdown]
# // CS 202 Provided Main
# //	This main tests the object in multiple ways...
#
# #include <iostream>
# #include <sstream>
# #include <iomanip>
# #include <string>
# #include "magicSquareType.h"
# using namespace std;
#
# // Class&Function Creation
# ////////////////////////////////////////
# class boardType
# {
# public:
# int size; // determines NxN size of magic square
# int ** board;
# static const intBSIZE_MIN=3;   // Minimum Size of the Board
# static const int BSIZE_MAX=50; // Maximum Size of the board
# int boardType(int);  // should verify the passed size (between SIZE_MIN and SIZE_MAX, inclusive)
# ~boardType(); //  should delete the dynamically allocated memory
# void setCell(int, int, int); // function should set the cell contents at the passed row and column location
# const int getCell(int, int); // function should return the cell contents at the passed row and column location (in that order)
# const int getOrder(); // function should return the board size
# const void printGrid(); //  function should print the grid in a formatted manner (with each value in a small text box)
# };
#
#
# ///////////////////////////
# const int getOrder()
# {  n = size;
#    return n;
# }
# ///////////////////////////
#
# ///////////////////////////
# ~boardType()
# {delete **board;
# }
# //////////////////////////
#
#
# ///////////////////////////
# int boardType(int)
# { if ( size<BSIZE_MIN && size >BSIZE_MAX)
# 	{return false;}
#   else
# 	{return true;}
# }
# ////////////////////////////////
#
#
#
#
#
# /////////////////////////////////////
#
# void makeMagic(magicSquareType &, bool);
# int main(int argc, char *argv[])
# {
# // ---------------
# //  Declarations...
#
# 	string stars;
# 	stars.append(60,'*');
# 	int	order;
# 	stringstream ss1;
#
# // ---------------
# //  Check for user provided command line args.
#
# 	if (argc > 1) {
# 		if (argc != 3) {
# 			cout << "Error, invalid command line arguments." << endl;
# 			return 0;
# 		}
#
# 		if (string(argv[1]) != "-o") {
# 			cout << "Error, must specify '-o' magic square order specifier." << endl;
# 			return 0;
# 		}
#
# 		ss1 << argv[2];
# 		ss1 >> order;
#
# 		magicSquareType mSqr1(order, "Test");
#
# 		makeMagic(mSqr1, true);
#
# 		return 0;
# 	}
#
# // ---------------
# //  Declare some magic squares.
# //  Use support routine to create magic square and display.
#
# 	magicSquareType mSqr3(3, "Test, Order 3");
# 	magicSquareType mSqr4(4, "Test, Order 4");
# 	magicSquareType mSqr5(5, "Test, Order 5");
# 	magicSquareType mSqr6(6, "Test, Order 6");
# 	magicSquareType mSqr8(8, "Test, Order 8");
# 	magicSquareType mSqr9(9, "Test, Order 9");
# 	magicSquareType mSqr10(10, "Test, Order 10");
# 	magicSquareType mSqr12(12, "Test, Order 12");
# 	magicSquareType mSqr13(13, "Test, Order 13");
# 	magicSquareType mSqr14(14, "Test, Order 14");
#
# 	makeMagic(mSqr3, true);
# 	makeMagic(mSqr4, true);
# 	makeMagic(mSqr5, true);
# 	makeMagic(mSqr6, true);
# 	makeMagic(mSqr8, true);
# 	makeMagic(mSqr9, true);
# 	makeMagic(mSqr10, true);
# 	makeMagic(mSqr12, true);
# 	makeMagic(mSqr13, true);
# 	makeMagic(mSqr14, true);
#
# // ---------------
# //  Read a two 3x3 magic squares form user.
#
# 	cout << stars << endl;
# 	cout << "Read Testing, 3x3..." << endl << endl;
#
# 	magicSquareType mSqr33(3, "Read Test #1");
#
# 	mSqr33.readMagicSquare();
# 	makeMagic(mSqr33, false);
#
# 	cout << endl << stars << endl;
#
# 	mSqr33.clearMagicSquare();
# 	mSqr33.readMagicSquare();
# 	makeMagic(mSqr33, false);
#
# 	cout << endl << endl;
#
# // ---------------
# //  Read an 11x11 magic square from user.
#
# 	cout << stars << endl;
# 	cout << "Read Testing, 11x11..." << endl << endl;
#
# 	magicSquareType mSqr11(11, "Read Test #2");
#
# 	mSqr11.readMagicSquare();
# 	makeMagic(mSqr11, false);
#
# 	cout << endl << stars << endl;
#
# 	mSqr11.clearMagicSquare();
# 	mSqr11.setTitle("Read Test #3");
# 	mSqr11.readMagicSquare();
# 	makeMagic(mSqr11, false);
#
# 	cout << endl << endl;
#
# // ---------------
# //  Read an 6x6 magic square from user.
#
# 	cout << stars << endl;
# 	cout << "Read Testing, 6x6..." << endl << endl;
#
# 	magicSquareType mSqr66(6, "Read Test #4");
#
# 	mSqr66.readMagicSquare();
# 	makeMagic(mSqr66, false);
#
# 	cout << endl << endl;
#
# // ---------------
# //  Read an 8x8 magic square from user.
#
# 	cout << stars << endl;
# 	cout << "Read Testing, 8x8..." << endl << endl;
#
# 	magicSquareType mSqr88(8, "Read Test #5");
#
# 	mSqr88.readMagicSquare();
# 	makeMagic(mSqr88, false);
#
# 	cout << endl << stars << endl;
#
# 	mSqr88.clearMagicSquare();
# 	mSqr88.setTitle("Read Test #6");
# 	mSqr88.readMagicSquare();
# 	makeMagic(mSqr88, false);
#
# 	cout << endl << endl;
#
# // ---------------
# //  All done, end program...
#
# 	return 0;
# }
#
#
# // ***********************************************************************
# //  Support routine for creating, printing, and validating
# //	a magic square.  Also, prints a cute message.
#
# void makeMagic(magicSquareType &mSqr, bool makeIt)
# {
# 	const char* green = "\033[0;32m";
# 	const char* white = "\033[0;37m";
# 	const char* red   = "\033[0;31m";
# 	const char* bold   = "\033[1m";
# 	const char* unbold   = "\033[0m";
#
# 	string stars;
# 	stars.append(60,'*');
#
# 	cout << endl << stars << endl << endl;
#
# 	if (makeIt)
# 		mSqr.createMagicSquare();
#
# 	mSqr.printMagicSquare();
#
# 	if ( mSqr.validateMagicSquare() )
# 		cout << bold << green << "Valid Magic Square."
# 			<< white << unbold << endl;
# 	else
# 		cout << bold << red << "Not a Magic Square Solution." <<
# 			white << unbold << endl;
# 	cout << endl;
#
# }

# %% [markdown]
# # Make file for CS 202 assignment #3, magic squares
#
# CC	= g++ -Wall -pedantic -Wextra -std=c++11 -g
# OBJS	= magic.o boardTypeImp.o magicSquareImp.o
# OBJS1	= bMain.o boardTypeImp.o
# DEPS	= boardType.h magicSquareType.h
# DEPS1	= boardType.h
#
# all: magic
#
# magic: $(OBJS)
# 	$(CC) -o magic $(OBJS)
#
# magic.o:	magic.cpp $(DEPS)
# 	$(CC) -c magic.cpp
#
# bMain: $(OBJS1)
# 	$(CC) -o bMain $(OBJS1)
#
# bMain.o:	bMain.cpp $(DEPS1)
# 	$(CC) -c bMain.cpp
#
# boardTypeImp.o:	boardTypeImp.cpp $(DEPS1)
# 	$(CC) -c boardTypeImp.cpp
#
# magicSquareImp.o: magicSquareImp.cpp $(DEPS)
# 	$(CC) -c magicSquareImp.cpp
#
# # -----
# # clean by removing object files.
#
# clean:
# 	rm -f $(OBJS)
# 	rm -f bMain.o
